# %% [markdown]
# <b>Image used</b>: Model Inputs - compressed - Small - 60_40 split - Denoised  <br>
# <b>Architecture used</b> -
#
# Changes from V4.4 -
# <ol>
#   <li>Input batch norm block removed</li>
#   <li>Dropouts removed</li>
# </ol>
#
# Training Acc - 86%, val acc - 88%<br>
# Recall - 100% for LAV, 45% for LDL

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Imports-&amp;-Path-Definitions" data-toc-modified-id="Imports-&amp;-Path-Definitions-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Imports &amp; Path Definitions</a></span><ul class="toc-item"><li><span><a href="#Package-imports" data-toc-modified-id="Package-imports-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Package imports</a></span></li><li><span><a href="#Connect-to-GDrive" data-toc-modified-id="Connect-to-GDrive-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Connect to GDrive</a></span></li><li><span><a href="#Check-and-unzip-the-Model-Input-files,-if-required" data-toc-modified-id="Check-and-unzip-the-Model-Input-files,-if-required-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Check and unzip the Model Input files, if required</a></span></li><li><span><a href="#Provide-input-configuration" data-toc-modified-id="Provide-input-configuration-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Provide input configuration</a></span></li></ul></li><li><span><a href="#Loading-dataset-using-Keras" data-toc-modified-id="Loading-dataset-using-Keras-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Loading dataset using Keras</a></span><ul class="toc-item"><li><span><a href="#Create-generators-to-source-training-and-test-data" data-toc-modified-id="Create-generators-to-source-training-and-test-data-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Create generators to source training and test data</a></span></li><li><span><a href="#Print-a-summary-of-train-&amp;-test-images" data-toc-modified-id="Print-a-summary-of-train-&amp;-test-images-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Print a summary of train &amp; test images</a></span></li><li><span><a href="#Test-Data-Generator" data-toc-modified-id="Test-Data-Generator-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Test Data Generator</a></span></li><li><span><a href="#Visualize-images" data-toc-modified-id="Visualize-images-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Visualize images</a></span></li></ul></li><li><span><a href="#Model-Definition" data-toc-modified-id="Model-Definition-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Model Definition</a></span><ul class="toc-item"><li><span><a href="#Architecture-Definition" data-toc-modified-id="Architecture-Definition-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Architecture Definition</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Test" data-toc-modified-id="Test-3.1.0.1"><span class="toc-item-num">3.1.0.1&nbsp;&nbsp;</span>Test</a></span></li></ul></li></ul></li><li><span><a href="#Visualize-model-Summary" data-toc-modified-id="Visualize-model-Summary-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Visualize model Summary</a></span></li><li><span><a href="#Callbacks-Definition" data-toc-modified-id="Callbacks-Definition-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Callbacks Definition</a></span></li><li><span><a href="#Define-Optimizers" data-toc-modified-id="Define-Optimizers-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Define Optimizers</a></span></li><li><span><a href="#Compile-model" data-toc-modified-id="Compile-model-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Compile model</a></span></li></ul></li><li><span><a href="#Train-Model" data-toc-modified-id="Train-Model-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Train Model</a></span></li><li><span><a href="#Model-Evaluation" data-toc-modified-id="Model-Evaluation-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Model Evaluation</a></span><ul class="toc-item"><li><span><a href="#Print-loss-history" data-toc-modified-id="Print-loss-history-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Print loss history</a></span></li><li><span><a href="#Loss-Curve" data-toc-modified-id="Loss-Curve-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Loss Curve</a></span><ul class="toc-item"><li><span><a href="#Training-Loss" data-toc-modified-id="Training-Loss-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Training Loss</a></span></li><li><span><a href="#Validation-loss" data-toc-modified-id="Validation-loss-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Validation loss</a></span></li><li><span><a href="#Summarized-View" data-toc-modified-id="Summarized-View-5.2.3"><span class="toc-item-num">5.2.3&nbsp;&nbsp;</span>Summarized View</a></span></li></ul></li><li><span><a href="#Confusion-matrix" data-toc-modified-id="Confusion-matrix-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Confusion matrix</a></span><ul class="toc-item"><li><span><a href="#Define-Helper-functions-to-get-predictions-for-images-in-a-folder" data-toc-modified-id="Define-Helper-functions-to-get-predictions-for-images-in-a-folder-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>Define Helper functions to get predictions for images in a folder</a></span></li><li><span><a href="#Define-helper-function-to-plot-confusion-matrix" data-toc-modified-id="Define-helper-function-to-plot-confusion-matrix-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>Define helper function to plot confusion matrix</a></span></li><li><span><a href="#Training-Data" data-toc-modified-id="Training-Data-5.3.3"><span class="toc-item-num">5.3.3&nbsp;&nbsp;</span>Training Data</a></span></li></ul></li><li><span><a href="#Test-Data" data-toc-modified-id="Test-Data-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Test Data</a></span></li><li><span><a href="#Plot-Images---Not-yet-completed" data-toc-modified-id="Plot-Images---Not-yet-completed-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Plot Images - Not yet completed</a></span><ul class="toc-item"><li><span><a href="#Helper-function-to-plot-images" data-toc-modified-id="Helper-function-to-plot-images-5.5.1"><span class="toc-item-num">5.5.1&nbsp;&nbsp;</span>Helper function to plot images</a></span></li><li><span><a href="#Plot-Misclassified-Images" data-toc-modified-id="Plot-Misclassified-Images-5.5.2"><span class="toc-item-num">5.5.2&nbsp;&nbsp;</span>Plot Misclassified Images</a></span></li></ul></li><li><span><a href="#Image-visualization-through-the-model" data-toc-modified-id="Image-visualization-through-the-model-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Image visualization through the model</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Imports & Path Definitions

# %% [markdown]
# ### Package imports

# %%
import warnings
warnings.filterwarnings('ignore')

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sn
from time import time

import imutils
import cv2
from math import ceil

from sklearn.utils import class_weight
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix

import keras
from keras import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D, Activation, Flatten, Dropout, GlobalAveragePooling2D, SpatialDropout2D
from keras.models import Sequential
from keras.layers import Dense, Activation, BatchNormalization
from keras.callbacks import TensorBoard, ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# %matplotlib inline

# %% [markdown]
# ### Connect to GDrive

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# ### Check and unzip the Model Input files, if required

# %%
# Delete folders if required
# !rm -rf "/content/5. Model Inputs"
# !rm -rf "/content/model_outputs"

# %%
# %%capture
# content/gdrive/My Drive/6. Model Inputs - Denoised.zip
# os.path.exists('/content/gdrive/My Drive/Model Inputs - compressed - Small - 60_40 split - Denoised.zip')
# !unzip -a '/content/gdrive/My Drive/Model Inputs - compressed - Small - 60_40 split - Denoised.zip'

# %% [markdown]
# ### Provide input configuration

# %%
PATH_IMAGES_TRAIN = '/content/5. Model Inputs - Denoised/train'
PATH_IMAGES_TEST = '/content/5. Model Inputs - Denoised/test'
PATH_OUTPUTS_MODEL = '/content/model_outputs'

# %%
BATCH_SIZE = 64
EPOCHS = 500

# %% [markdown]
# Set image size based on whether a large or small image is chosen

# %%
## Large images
# IMG_WIDTH = 816
# IMG_HEIGHT = 612

## Small images
IMG_WIDTH = 408
IMG_HEIGHT = 306

# %% [markdown]
# ## Loading dataset using Keras

# %% [markdown]
# ### Create generators to source training and test data

# %%
generator_data_train = ImageDataGenerator(rescale=1 / 255).flow_from_directory(
    PATH_IMAGES_TRAIN,
    target_size=(IMG_WIDTH, IMG_HEIGHT),
    batch_size=BATCH_SIZE,
    class_mode='categorical')
# Out:
# Found 1292 images belonging to 4 classes.

# %%
generator_data_test = ImageDataGenerator(rescale=1 / 255).flow_from_directory(
    PATH_IMAGES_TEST,
    target_size=(IMG_WIDTH, IMG_HEIGHT),
    batch_size=BATCH_SIZE,
    class_mode='categorical')
# Out:
# Found 51 images belonging to 4 classes.

# %% [markdown]
# ### Print a summary of train & test images

# %% [markdown]
# Train images

# %%
generator_data_train.n
generator_data_train.class_indices

pd.Series(generator_data_train.labels).value_counts()
generator_data_train.image_shape
# Out:
# 1292
# {'defective_lav': 0,
#  'defective_ldl': 1,
#  'non_defective': 2,
#  'non_defective_bubbles': 3}
# 2    561
# 3    374
# 1    187
# 0    170
# dtype: int64
# (408, 306, 3)

# %% [markdown]
# Test images

# %% [markdown]
# ### Test Data Generator

# %%
generator_data_test.n
generator_data_test.class_indices

pd.Series(generator_data_test.labels).value_counts()
generator_data_test.image_shape
# Out:
# 51
# {'defective_lav': 0,
#  'defective_ldl': 1,
#  'non_defective': 2,
#  'non_defective_bubbles': 3}
# 2    23
# 3    15
# 1     7
# 0     6
# dtype: int64
# (408, 306, 3)

# %% [markdown]
# ### Visualize images

# %%
x = cv2.imread(os.path.join(PATH_IMAGES_TRAIN,"defective_lav/aug_0.jpg"))

# %%
x.shape
# Out:
# (306, 408, 3)

# %%
plt.imshow(x)

# %% [markdown]
# ## Model Definition

# %% [markdown]
# ### Architecture Definition

# %%
# Dropout Rate (1-rate)
rate = 0.9
# Kernel Size
KERNEL_SIZE = (3,3)

# %%
model = Sequential()
# model.add(BatchNormalization(input_shape= generator_data_train.image_shape))

# Conv Block 1

# 3 conv2d layers, with filter size = 8
model.add(Conv2D(filters = 8,
                    kernel_size = KERNEL_SIZE,
                    padding = 'same',
                 activation='relu',
                 input_shape= generator_data_train.image_shape
                ))
model.add(BatchNormalization())
model.add(Conv2D(filters = 8,
                    kernel_size = KERNEL_SIZE,
                    padding = 'same',
                 activation='relu',
                ))
model.add(BatchNormalization())
model.add(Conv2D(filters = 8,
                    kernel_size = KERNEL_SIZE,
                    padding = 'same',
                 activation='relu',
                ))
model.add(BatchNormalization())


model.add(MaxPool2D(pool_size=(2,2)))


# Layer 2
model.add(Conv2D(filters = 16,
                    kernel_size = KERNEL_SIZE,
#                    strides = (1,1),
                    padding = 'same',
                activation='relu'
                ))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2,2)))



# Layer 3
model.add(Conv2D(filters = 32,
                    kernel_size = KERNEL_SIZE,
                 activation='relu'
                ))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2,2)))

# Layer 4
model.add(Conv2D(filters = 64,
                    kernel_size = KERNEL_SIZE,
                                  activation='relu'
                ))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2,2)))

# Layer 4b
model.add(Conv2D(filters = 128,
                    kernel_size = KERNEL_SIZE))
model.add(BatchNormalization())
model.add(Conv2D(filters = 128,
                    kernel_size = KERNEL_SIZE))

# Layer 5
model.add(GlobalAveragePooling2D())

# Layer 6
model.add(Dense(4))
model.add(Activation('softmax'))

# %% [markdown]
# ##### Test

# %%
# model = Sequential()
# model.add(BatchNormalization(input_shape= generator_data_train.image_shape))

# # Layer 1
# model.add(Conv2D(filters = 8,
#                     kernel_size = KERNEL_SIZE,
# #                    strides = (1,1),
#                     padding = 'same',
# #                  activation='relu'
#                 ))
# model.add(BatchNormalization())
# model.add(MaxPool2D(pool_size=(2,2)))
# model.add(Dropout(1-rate))

# # Layer 2
# model.add(Conv2D(filters = 16,
#                     kernel_size = KERNEL_SIZE,
# #                    strides = (1,1),
#                     padding = 'same',
# #                 activation='relu'
#                 ))
# model.add(BatchNormalization())
# model.add(MaxPool2D(pool_size=(2,2)))
# model.add(Dropout(1-rate))

# # Layer 3
# model.add(Conv2D(filters = 32,
#                     kernel_size = KERNEL_SIZE,
# #                 activation='relu'
#                 ))
# model.add(BatchNormalization())
# model.add(MaxPool2D(pool_size=(2,2)))
# model.add(Dropout(1-rate))

# # Layer 4
# model.add(Conv2D(filters = 64,
#                     kernel_size = KERNEL_SIZE,
#                 activation='relu'))
# #                    strides = (1,1),
# #                    padding = 'valid'))
# model.add(BatchNormalization())
# model.add(MaxPool2D(pool_size=(2,2)))

# # Layer 4b
# model.add(Conv2D(filters = 128,
#                     kernel_size = KERNEL_SIZE,
#                 activation='relu'))
# #                    strides = (1,1),
# #                    padding = 'valid'))
# # model.add(BatchNormalization())
# # model.add(MaxPool2D(pool_size=(2,2)))

# ## Flatten
# model.add(Flatten())

# # Layer 5
# model.add(Dense(16,
#             kernel_initializer ='glorot_normal'))
# model.add(BatchNormalization())
# model.add(Activation('relu'))
# model.add(Dropout(1-rate))

# # Layer 6
# model.add(Dense(32,kernel_initializer ='glorot_normal'))
# model.add(BatchNormalization())
# model.add(Activation('relu'))
# model.add(Dropout(1-rate))

# # Layer 7
# model.add(Dense(4))
# model.add(Activation('softmax'))

# %% [markdown]
# ### Visualize model Summary

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_23 (Conv2D)           (None, 408, 306, 8)       224
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 408, 306, 8)       32
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 408, 306, 8)       584
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 408, 306, 8)       32
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 408, 306, 8)       584
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 408, 306, 8)       32
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 204, 153, 8)       0
# ...

# %% [markdown]
# ### Callbacks Definition

# %% [markdown]
# Set Class Weights to be able to handle unbalanced data

# %%
# Set class weights
classes_values = list(generator_data_train.class_indices.values())
class_weights = class_weight.compute_class_weight('balanced',classes_values,generator_data_train.labels) 
class_weights
# Out:
# array([1.9       , 1.72727273, 0.57575758, 0.86363636])

# %%
# Proof that it works
x = pd.DataFrame({'vol_unweighted':pd.Series(generator_data_train.labels).value_counts().sort_index()}) 
x['weight'] = class_weights
x['vol_weighted'] = x['vol_unweighted']*x['weight']
x
# Out:
#    vol_unweighted    weight  vol_weighted
# 0             170  1.900000         323.0
# 1             187  1.727273         323.0
# 2             561  0.575758         323.0
# 3             374  0.863636         323.0

# %%
dict(zip(classes_values,class_weights))
# Out:
# {0: 1.9, 1: 1.7272727272727273, 2: 0.5757575757575758, 3: 0.8636363636363636}

# %% [markdown]
# Tensorboard configuration

# %%
if not os.path.exists(PATH_OUTPUTS_MODEL):
  os.mkdir(PATH_OUTPUTS_MODEL)

# %%
tensorboard = TensorBoard(log_dir=os.path.join(PATH_OUTPUTS_MODEL,'logs'),
                          histogram_freq=1,
                          batch_size=BATCH_SIZE,
                          write_graph=True,
                          write_grads=True,
                          write_images=True,
                          embeddings_freq=1,
                          update_freq='EPOCHS')

# %% [markdown]
# Tracking Loss History

# %%
class LossHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.losses = []

    def on_batch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))


loss_history = LossHistory()

# %%
patience = 15
callback_list = [
    EarlyStopping(monitor='val_loss', patience=patience),
    ModelCheckpoint(filepath=os.path.join(PATH_OUTPUTS_MODEL,'Final_project1.h5'), save_best_only=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=patience),
#     tensorboard,
    loss_history
]

# %% [markdown]
# ### Define Optimizers

# %%
optimizer_adam = keras.optimizers.Adam(lr=0.001,
                                       beta_1=0.9,
                                       beta_2=0.999,
                                       epsilon=1e-08,
                                       decay=0.0)

# %% [markdown]
# ### Compile model

# %%
model_compile_metrics = ['accuracy']
model_compile_loss = 'categorical_crossentropy'

# %%
model.compile(optimizer=optimizer_adam,
                 loss=model_compile_loss,
                 metrics=model_compile_metrics)

# %% [markdown]
# ## Train Model

# %%
# New Model
history_v3 = model.fit_generator(
    generator_data_train,
    epochs=EPOCHS,
    steps_per_epoch=generator_data_train.n / BATCH_SIZE,
    validation_steps=generator_data_test.n / BATCH_SIZE,
    shuffle=True,
    callbacks=callback_list,
    class_weight=dict(zip(classes_values,class_weights)),
    validation_data=generator_data_test)
# Out:
# Epoch 1/500
# 21/20 [===============================] - 14s 659ms/step - loss: 1.2456 - acc: 0.4558 - val_loss: 0.9650 - val_acc: 0.5490
# Epoch 2/500
# 21/20 [===============================] - 7s 350ms/step - loss: 1.0961 - acc: 0.5894 - val_loss: 0.7569 - val_acc: 0.8039
# Epoch 3/500
# 21/20 [===============================] - 7s 353ms/step - loss: 0.9713 - acc: 0.6493 - val_loss: 0.6489 - val_acc: 0.8235
# Epoch 4/500
# 21/20 [===============================] - 7s 357ms/step - loss: 0.9009 - acc: 0.6731 - val_loss: 0.6661 - val_acc: 0.7843
# Epoch 5/500
# 21/20 [===============================] - 8s 362ms/step - loss: 0.8336 - acc: 0.7143 - val_loss: 0.6329 - val_acc: 0.8039
# Epoch 6/500
# 21/20 [===============================] - 8s 363ms/step - loss: 0.8000 - acc: 0.7150 - val_loss: 0.6183 - val_acc: 0.8235
# Epoch 7/500
# 21/20 [===============================] - 8s 368ms/step - loss: 0.7889 - acc: 0.7271 - val_loss: 0.5994 - val_acc: 0.8235
# Epoch 8/500
# ...

# %%
# link to be pasted on anaconda terminal for launching tensorboard
#tensorboard --logdir=C:\Users\Priyank\logs
# http://localhost:6006

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# ### Print loss history

# %%
plt.plot(loss_history.losses)
plt.title('Loss after each Iteration')

plt.show()
# Out:
# Text(0.5, 1.0, 'Loss after each Iteration')

# %% [markdown]
# ### Loss Curve

# %% [markdown]
# #### Training Loss

# %%
# plot loss curve
plt.plot(history_v3.history['loss'], label='training')
plt.title('Training Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
# Out:
# Text(0.5, 1.0, 'Training Model loss')
# Text(0, 0.5, 'Loss')
# Text(0.5, 0, 'Epoch')

# %% [markdown]
# #### Validation loss

# %%
plt.plot(history_v3.history['val_loss'], label='test')
plt.title('Validation Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
# Out:
# Text(0.5, 1.0, 'Validation Model loss')
# Text(0, 0.5, 'Loss')
# Text(0.5, 0, 'Epoch')

# %% [markdown]
# #### Summarized View

# %%
pd.DataFrame(history_v3.history).plot()

# %% [markdown]
# ### Confusion matrix

# %% [markdown]
# #### Define Helper functions to get predictions for images in a folder

# %%
def get_predictions(path):
  # Runs predictions for all images in a path (Structured similar to train/test folders) and returns a dataframe with the image, y_actual, y_predicted
  # Assumes the images in the path need to be rescaled to 1/255, have a target_size = IMG_WIDTH,IMG_HEIGHT (Defined in the code)
  dummy_gen = ImageDataGenerator(rescale=1/255).flow_from_directory(
      path,
      target_size=(IMG_WIDTH, IMG_HEIGHT),
      batch_size=2000,
      shuffle=False,
      class_mode='categorical')
  img,y_actual = next(dummy_gen)

  y_actual = np.argmax(y_actual,axis=1)

  y_pred = np.argmax(model.predict(img),axis=1)
#   return pd.DataFrame({'image':img,
#                       'y_actual':y_actual,
#                       'y_pred':y_pred})
  filepaths = dummy_gen.filepaths
  return img,y_actual,y_pred, filepaths

# %%
mapping_labels = dict((val,key) for key,val in generator_data_train.class_indices.items())
mapping_labels
# Out:
# {0: 'defective_lav',
#  1: 'defective_ldl',
#  2: 'non_defective',
#  3: 'non_defective_bubbles'}

# %%
classes = [
    'defective_lav', 'defective_ldl', 'non_defective', 'non_defective_bubbles'
]

# %%
def get_labels(array):
  return pd.Series(array).replace(mapping_labels)

# %% [markdown]
# #### Define helper function to plot confusion matrix

# %%
# Source - https://gist.github.com/hitvoice/36cf44689065ca9b927431546381a3f7
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix


def cm_analysis(y_true, y_pred, filename, labels, ymap=None, figsize=(10, 10)):
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    if ymap is not None:
        y_pred = [ymap[yi] for yi in y_pred]
        y_true = [ymap[yi] for yi in y_true]
        labels = [ymap[yi] for yi in labels]
    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax)
    plt.savefig(filename)

# %% [markdown]
# #### Training Data

# %% [markdown]
# Get Predictions

# %%
images, y_true, y_pred, filepaths = get_predictions(PATH_IMAGES_TRAIN)
# Out:
# Found 1292 images belonging to 4 classes.

# %%
# Print Results
pd.Series(y_true==y_pred).value_counts()
# Out:
# True     1146
# False     146
# dtype: int64

# %% [markdown]
# Print Confusion matrix

# %%
cm_analysis(get_labels(y_true), get_labels(y_pred),filename=os.path.join(PATH_OUTPUTS_MODEL,"Confusion matrix - train.png"),
            labels=classes,figsize=(5,5))

# %% [markdown]
# Print Classification Report

# %%
print(classification_report(y_true,y_pred,target_names=classes))
# Out:
#                        precision    recall  f1-score   support
#
#         defective_lav       0.61      0.95      0.74       170
#         defective_ldl       0.90      0.96      0.93       187
#         non_defective       0.97      0.81      0.88       561
# non_defective_bubbles       0.98      0.95      0.96       374
#
#              accuracy                           0.89      1292
#             macro avg       0.86      0.91      0.88      1292
#          weighted avg       0.91      0.89      0.89      1292

# %% [markdown]
# ### Test Data

# %% [markdown]
# Get Predictions

# %%
images_test, y_true_test, y_pred_test, filepaths_test = get_predictions(PATH_IMAGES_TEST)
# Out:
# Found 51 images belonging to 4 classes.

# %%
# Print Results
pd.Series(y_true_test==y_pred_test).value_counts()
# Out:
# True     45
# False     6
# dtype: int64

# %% [markdown]
# Print Confusion matrix

# %%
cm_analysis(get_labels(y_true_test), get_labels(y_pred_test),filename=os.path.join(PATH_OUTPUTS_MODEL,"Confusion matrix - test.png"),
            labels=classes,figsize=(5,5))

# %% [markdown]
# Print Classification Report

# %%
print(classification_report(y_true_test,y_pred_test,target_names=classes))
# Out:
#                        precision    recall  f1-score   support
#
#         defective_lav       0.75      1.00      0.86         6
#         defective_ldl       1.00      0.43      0.60         7
#         non_defective       0.85      0.96      0.90        23
# non_defective_bubbles       1.00      0.93      0.97        15
#
#              accuracy                           0.88        51
#             macro avg       0.90      0.83      0.83        51
#          weighted avg       0.90      0.88      0.87        51

# %% [markdown]
# ### Plot Images - Not yet completed

# %% [markdown]
# #### Helper function to plot images

# %%
# Figure (incl all subplots)'s Height, Width in inches
FIGSIZE = (12,20)

# %%
def plot_images(**kwargs):
    """
    List of images to show, with the variable name used as the plot title
    """
    num_images = len(kwargs)
    columns = 2
    rows = ceil(num_images/2)

    fig = plt.figure(figsize=FIGSIZE,facecolor="None")
    
   # ax enables access to manipulate each of subplots
    ax = []
    i=0

    for key,val in kwargs.items():
        # create subplot and append to ax
        ax.append( fig.add_subplot(rows, columns, i+1) )
        plt.imshow(imutils.opencv2matplotlib(val))
        
        ax[-1].set_title(key,fontdict={'fontsize':12,'color':'red'})  # set title
        i+=1
    plt.axis('off')
    plt.tight_layout()
    plt.show()  # finally, render the plot

def read_and_plot_images_base_dir(path_base, list_names_img):
    """
    Reads images from a base directory and plots them
    """
    list_imgs = [cv2.imread(os.path.join(path_base,name_img)) for name_img in list_names_img]
    
#     height,width = list_imgs[0].shape[0],list_imgs[0].shape[1]
#     print(height,width)
#     plt.rcParams['figure.figsize'] = (width,height)
    
    plot_args = dict(zip(list_names_img,list_imgs))
    plot_images(**plot_args)

def read_and_plot_images_paths(list_paths):
    """
    Takes a list of image paths, and plots them
    """
    list_imgs = [cv2.imread(path) for path in list_paths]
    
#     height,width = list_imgs[0].shape[0],list_imgs[0].shape[1]
#     print(height,width)
#     plt.rcParams['figure.figsize'] = (width,height)
    list_names_images = list(map(lambda x:os.path.basename(x), list_paths))
    
    plot_args = dict(zip(list_names_images,list_imgs))
    plot_images(**plot_args)

# %% [markdown]
# #### Plot Misclassified Images

# %%
# What were the predictions?
data_result = pd.DataFrame({'path':filepaths_test,
             'y_pred':y_pred_test,
            'y_true':y_true_test})
# Add labels for y_pred/y_true and also get filenames
data_result['y_pred'] = data_result['y_pred'].apply(get_labels)
data_result['y_true'] = data_result['y_true'].apply(get_labels)
data_result['filename'] = data_result['path'].apply(os.path.basename)

# Were the predictions correct?

data_result['flag_pred_correct'] = data_result['y_pred']==data_result['y_true']

# %%
list_paths_images_misclassified = data_result[data_result['flag_pred_correct']==False]['path'].to_list()
# images_test, y_true_test, y_pred_test, filepaths_test

# %%
read_and_plot_images_paths(list_paths_images_misclassified)

# %%
# What were the predictions?
data_result[data_result['flag_pred_correct']==False]
# Out:
#                                                  path  ... flag_pred_correct
# 0   /content/5. Model Inputs - Denoised/test/defec...  ...             False
# 4   /content/5. Model Inputs - Denoised/test/defec...  ...             False
# 6   /content/5. Model Inputs - Denoised/test/defec...  ...             False
# 9   /content/5. Model Inputs - Denoised/test/defec...  ...             False
# 16  /content/5. Model Inputs - Denoised/test/non_d...  ...             False
# 17  /content/5. Model Inputs - Denoised/test/non_d...  ...             False
# 23  /content/5. Model Inputs - Denoised/test/non_d...  ...             False
# 41  /content/5. Model Inputs - Denoised/test/non_d...  ...             False
# 42  /content/5. Model Inputs - Denoised/test/non_d...  ...             False
#
# [9 rows x 5 columns]

# %% [markdown]
# ### Image visualization through the model

# %% [markdown]
# Helper function to get y_actuals, y_pred for each image in a folder

# %% [markdown]
# Get Correctly classified & misclassified images

# %%
pred_correct = [] #Contains image only
pred_incorrect = [] #Contains image, actual, prediction values

for i in range(y_true.size):
    if y_true[i] == y_pred[i]:
        pred_correct.append(images[i])
    else:
        pred_incorrect.append((images[i],y_true[i],y_pred[i]))

# %% [markdown]
# Next Steps:
#
#
# 1.   Grayscale - Priyank
# 2.   Denoised image - Shyam
# 3.   Mean Centering - Shyam
# 4.   Dropouts - Priyank
# 5.   Activations, Regularizations - Ganga
# 5.   Transfer Learning - Vivek
# 6.   Get confusion matrix report for different types of augmentations (training and test) - Ganga
